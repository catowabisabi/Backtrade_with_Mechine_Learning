# %%
import matplotlib
import matplotlib_inline
import pandas as pd
from IPython.display import display
# %matplotlib inline

# %% [markdown]
# 1. 得到所有文件夾內的DF and Prediction

# %%
from functional_class.class_folder_reader import FolderReader



share_ta_folder_path = "Y:/TrueNas_4TB_A/Coding Share/ta_data/test"
folder_reader = FolderReader(share_ta_folder_path, "train")
dataframes = folder_reader.read_csv_files() # List of df

#呢度得到所有文件夾內的有df, 呢D df係有prediction的

# %% [markdown]
# 2. 得到所有models 清單

# %%
from functional_class.class_model_scanner import ModelScanner

share_models_folder_path = "Y:/TrueNas_4TB_A/Coding Share/models/backtest_models"
model_scanner = ModelScanner(share_models_folder_path)
settings_list, model_folder_list = model_scanner.scan_models()

# %% [markdown]
# 2B. 得到所有models

# %%
from models.model_define.InceptionTime.train_class_inception_time_v2 import StockInceptionTime
from functional_class.model_initializer import ModelInitializer


# 初始化模型
model_initializer = ModelInitializer(settings_list, model_folder_list)
model_initializer.initialize_models()
inc_model_list = model_initializer.get_models() # "得到 一個 文件清單 中的 模型清單 [[model1 model2], [model3 model4 model4]...]"

# %%
from config.config import features_3
from functional_class.class_backtest import Backtest

#文件夾一定要有文件
backtest = Backtest(ticker="CHTR", slp=2, tpp=2, com=0.1)
backtest.run()
# Out:
# 回測所用的資料由這文件讀取: predict_csv/0_CHTR_predict.csv
# 數據讀取完畢！
# 已移除特徵：['PREDICT_TARGET']
# c:\Users\Chris\Desktop\ML\BT\BackTrader_w_MechLearn\strategies\golden_cross.py:63: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.data_log = pd.concat([self.data_log, new_entry], ignore_index=True)

# %%
from config.config import features_0, features_1, features_2, features_3, features_5

print(features_3)
